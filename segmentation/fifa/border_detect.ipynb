# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('images/screen_matches/0DF1AA42B9.jpg')
img2 = cv2.imread('images/screen_matches/0G1UJLATWE.jpg')
plt.figure(figsize=(14,8))
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
img1.shape
# Out:
# (616, 1125, 3)

# %%
img2.shape
# Out:
# (2286, 3264, 3)

# %%
a=cv2.resize(img1,(300,300))
b=cv2.resize(img2,(300,300))

# %%
c = cv2.addWeighted(a,0.6, b, 0.4, 0)
plt.imshow(cv2.cvtColor(c, cv2.COLOR_BGR2RGB))

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
ret, mask = cv2.threshold(gray, 210, 250, cv2.THRESH_BINARY_INV)
plt.imshow(mask, cmap='gray')

# %%
ret, mask = cv2.threshold(gray, 200, 250, cv2.THRESH_BINARY)
plt.imshow(mask, cmap='gray')
